# %%
import pandas as pd
import quandl
from statsmodels.tsa.seasonal import seasonal_decompose
import KEYS

# %%
QUANDL_KEY = KEYS.QUANDL_KEY
quandl.ApiConfig.api_key = QUANDL_KEY

df = quandl.get(
    dataset='WGC/GOLD_MONAVG_USD',
    start_date='2000-01-01',
    end_date='2011-12-31'
)

df.rename(columns={'Value':'price'}, inplace=True)
df = df.resample('M').last()

# %%
WINDOW_SIZE = 12
df['rolling_mean'] = df.price.rolling(window=WINDOW_SIZE).mean()
df['rolling_std'] = df.price.rolling(window=WINDOW_SIZE).std()
df.plot(title='Gold Price')

# %%
df.tail()
# Out:
#               price  rolling_mean  rolling_std
# Date
# 2011-08-31  1755.81   1447.342500   130.729234
# 2011-09-30  1771.85   1489.081667   148.105291
# 2011-10-31  1665.21   1516.014167   148.316826
# 2011-11-30  1738.98   1546.771667   153.441103
# 2011-12-31  1652.31   1568.585000   147.712610

# %%
decomposition_results = seasonal_decompose(df.price, model='multiplicative')
decomposition_results.plot().suptitle('Multiplicative Decomposition', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Multiplicative Decomposition')

# %%
decomposition_results = seasonal_decompose(df.price, model='additive')
decomposition_results.plot().suptitle('Additive Decomposition', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Additive Decomposition')

# %% [markdown]
# 추세, 계절성, 랜덤성을 볼 수 있다.(4요소 - 레벨, 추세, 계절성 + 랜덤성(비체계))

# %%
import pandas as pd
import seaborn as sns
import quandl

# %%
import pystan
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\frank\data_analysis\mystudy\study-finance\03.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/frank/data_analysis/mystudy/study-finance/03.ipynb#ch0000008?line=0'>1</a> import pystan
#
# ModuleNotFoundError: No module named 'pystan'
